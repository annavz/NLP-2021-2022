# %%
import pandas as pd
import gzip
import nltk
from nltk.collocations import *
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer
from nltk.metrics.spearman import *
import re
import RAKE
from nltk.corpus import stopwords
from collections import Counter, OrderedDict
from tqdm.notebook import tqdm

# %% [markdown]
# ### Загрузка данных

# %%
def parse(path):
    g = gzip.open(path, 'rb')
    for l in g:
        yield eval(l)

def getDF(path):
    i = 0
    df = {}
    for d in parse(path):
        df[i] = d
        i += 1
    return pd.DataFrame.from_dict(df, orient='index')

files = getDF('Magazine_Subscriptions_edited.json.gz').dropna(axis=0, subset=['reviewText'])
meta = getDF('meta_Magazine_Subscriptions.json.gz')

# %% [markdown]
# ### Предлагаемые способы:
#
# 1. Обучить реккурентную есть, которая будет классифицировать каждое слово на предмет того, входит ли оно в состав именованой сущности. В качестве данных должен выступать размеченный текст, где будут размечены сами именованные сущности, а также их границы, и в этом заключается основная трудоемкость задачи. Помимо этого, такой подход не позволит разметить вложенные именованные сущности. Однако это data-driven подход и в целом может дать достаточно качественные результаты.
#
# 2. Следующий подход основывается на правилах. Он подходит больше для простых именованных сущностей вроде даты, у которой ограниченный список того, как ее можно задать. Для более сложных ИС подход достаточно топорный, можно пропустить много именованных сущностей, а также он предполагает ручной анализ некоторого количества материала, либо наличие метаданных для составления правил. Однако, если материала очень много и весь он единой тематики, подход может подойти.
#
# 3. В конце концов, можно выделить ключевые слова и коллокации, затем отфильтровать их вручную и расширить список, подобрав синонимы для дискрипторов.

# %% [markdown]
# ### Реализация
# Большое количество уже выделенных именованных сущностей можно получить из метаданных.

# %%
titles = meta['title'].unique().tolist()
titles.remove('<span class="a-size-medium a-color-secondary"')
titles.remove(' Magazines" />')
titles = [re.sub(r' \(\d+?-[a-zA-Z]+?\)', '', t) for t in titles]

# %% [markdown]
# Еще более короткие названия можно посмотреть в в брендах/публикаторах: словосочетания N + Magazine содержат название.

# %%
brands = meta['brand'].unique().tolist()
brands = [b for b in brands if 'Magazine' in b]
brands_add = [re.sub(' Magazine', '@', b) for b in brands if ' Magazine' in b]
brands_add = [b.split('@')[0] for b in brands]
brands + brands_add
# Out:
# ['Reason Magazine',
#  'Hearst Magazines',
#  "Harper's Magazine",
#  'Golf Magazine',
#  'Home Business Magazine',
#  'Vermont Life Magazine',
#  'Natural History Magazine Inc',
#  'The Chelsea Magazine Company',
#  'F&W (Magazines)',
#  'Strand Magazine',
#  'Breakthrough Magazine',
#  'D Magazine Partners',
#  'Dermascope Magazine',
#  'New Art Publ/Bomb Magazine',
#  'Dirtrag Magazine',
#  'Emmanuel Magazine',
#  'Hearst Magazines UK',
#  'Living Blues Magazine',
#  'Man at Arms Magazine',
#  'Moorshead Magazines Ltd',
#  'Montana Magazine',
#  'New Mexico Magazine',
#  'Nebraska Life Magazine',
#  'St Louis Magazine Llc',
#  'Porthole Magazine',
#  'Sacramento Magazines Corp',
#  'Relix Magazine Inc',
#  'Texas Highways Magazine',
#  'Signcraft Magazine',
#  'South Dakota Magazine',
#  'Make-Up Artist Magazine',
#  'Universal Magazines Pty Ltd',
#  'Hearst Magazines Italia Spa',
#  'F&amp;W (Magazines)',
#  'Philadelphia Magazine',
#  'National Magazine Company Ltd',
#  'Reunions/Magazine/Inc',
#  'Geographical Magazine Ltd',
#  'Bonnier Magazines & Brands',
#  'Donna Hay Magazine',
#  'International Tourism Magazine Ltd',
#  'Bear Hunting Magazine',
#  'MusicMaker Magazine',
#  'New York Magazine',
#  'Skitrax Magazine',
#  'Old Schoolhouse Magazine',
#  'World Magazine Inc',
#  'Enterprise Magazines Inc',
#  'Idaho Magazine',
#  'Irish America Magazine',
#  'Alternative Press Magazine, Inc.',
#  'Walrus Magazine Inc',
#  'Citydog Magazine',
#  'Fish Alaska Magazine',
#  'D the Magazine of Dallas',
#  'Cruisin Style Magazine Inc',
#  'Sojourners Magazine',
#  'New England Home Magazine, LLC',
#  'Shotguns Sports Magazine, Inc.',
#  'Northern Virginia Magazine',
#  'Nickelodeon Magazine',
#  'Mutineer Magazine %J Dorenbush',
#  'Orlando Style Magazine Llc',
#  'Thuries Magazine',
#  'San Diego Magazine LLC',
#  'Washingtonian Magazine',
#  'Chesapeake Bay Magazine',
#  'Home & Design Magazine',
#  'Massage Magazine',
#  'Rattle Magazine',
#  'Chopchop Magazine',
#  'People Magazine',
#  'Allergic Living Magazine',
#  'Cowgirl Magazine',
#  'TV Guide Magazine Group',
#  'Time Magazine October 28, 2013',
#  'Red Bulletin Magazine',
#  'Hello Magazine',
#  'Paleo Magazine',
#  'The Time Inc. Magazine Company',
#  'Reason Magazine',
#  'Hearst Magazines',
#  "Harper's Magazine",
#  'Golf Magazine',
#  'Home Business Magazine',
#  'Vermont Life Magazine',
#  'Natural History Magazine Inc',
#  'The Chelsea Magazine Company',
#  'F&W (Magazines)',
#  'Strand Magazine',
#  'Breakthrough Magazine',
#  'D Magazine Partners',
#  'Dermascope Magazine',
#  'New Art Publ/Bomb Magazine',
#  'Dirtrag Magazine',
#  'Emmanuel Magazine',
#  'Hearst Magazines UK',
#  'Living Blues Magazine',
#  'Man at Arms Magazine',
#  'Moorshead Magazines Ltd',
#  'Montana Magazine',
#  'New Mexico Magazine',
#  'Nebraska Life Magazine',
#  'St Louis Magazine Llc',
#  'Porthole Magazine',
#  'Sacramento Magazines Corp',
#  'Relix Magazine Inc',
#  'Texas Highways Magazine',
#  'Signcraft Magazine',
#  'South Dakota Magazine',
#  'Make-Up Artist Magazine',
#  'Universal Magazines Pty Ltd',
#  'Hearst Magazines Italia Spa',
#  'F&amp;W (Magazines)',
#  'Philadelphia Magazine',
#  'National Magazine Company Ltd',
#  'Reunions/Magazine/Inc',
#  'Geographical Magazine Ltd',
#  'Bonnier Magazines & Brands',
#  'Donna Hay Magazine',
#  'International Tourism Magazine Ltd',
#  'Bear Hunting Magazine',
#  'MusicMaker Magazine',
#  'New York Magazine',
#  'Skitrax Magazine',
#  'Old Schoolhouse Magazine',
#  'World Magazine Inc',
#  'Enterprise Magazines Inc',
#  'Idaho Magazine',
#  'Irish America Magazine',
#  'Alternative Press Magazine, Inc.',
#  'Walrus Magazine Inc',
#  'Citydog Magazine',
#  'Fish Alaska Magazine',
#  'D the Magazine of Dallas',
#  'Cruisin Style Magazine Inc',
#  'Sojourners Magazine',
#  'New England Home Magazine, LLC',
#  'Shotguns Sports Magazine, Inc.',
#  'Northern Virginia Magazine',
#  'Nickelodeon Magazine',
#  'Mutineer Magazine %J Dorenbush',
#  'Orlando Style Magazine Llc',
#  'Thuries Magazine',
#  'San Diego Magazine LLC',
#  'Washingtonian Magazine',
#  'Chesapeake Bay Magazine',
#  'Home & Design Magazine',
#  'Massage Magazine',
#  'Rattle Magazine',
#  'Chopchop Magazine',
#  'People Magazine',
#  'Allergic Living Magazine',
#  'Cowgirl Magazine',
#  'TV Guide Magazine Group',
#  'Time Magazine October 28, 2013',
#  'Red Bulletin Magazine',
#  'Hello Magazine',
#  'Paleo Magazine',
#  'The Time Inc. Magazine Company']

# %%
meta_collocations = titles + brands_add

# %% [markdown]
# Логично предположить, что в отзывах ключевыми словами будут товары, о которых идет речь. Применим эти алгоритмы, чтобы найти какие-то дескрипторы или более общие упоминания. Алгоритму сложно обработать сразу все тексты, поэтому будем просматривать частями.

# %%
tokenizer = RegexpTokenizer(r"[a-zA-Z0-9]+")
lemmatizer = WordNetLemmatizer()
def normalize(text):
    lemmas = []
    for t in tokenizer.tokenize(text):
        lemmas.append(lemmatizer.lemmatize(t).lower())
    return lemmas

# %%
stop = stopwords.words('english')
rake = RAKE.Rake(stop)

# %%
files.shape
# Out:
# (89656, 12)

# %%
tok_texts = files['reviewText'][10000:20000].apply(normalize)
tok_texts = tok_texts.tolist()
tokens = []
for i in range(len(tok_texts)):
    tokens.extend(tok_texts[i])
tokens = ' '.join(tokens)

# %%
rake.run(tokens, maxWords=2, minFrequency=10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-3ae236421279> in <module>
# ----> 1 rake.run(tokens, maxWords=2, minFrequency=10)
#
# ~\anaconda3\lib\site-packages\RAKE\RAKE.py in run(self, text, minCharacters, maxWords, minFrequency)
#     168         word_scores = calculate_word_scores(phrase_list)
#     169
# --> 170         keyword_candidates = generate_candidate_keyword_scores(phrase_list, word_scores, minFrequency)
#     171
#     172         sorted_keywords = sorted(keyword_candidates.items(), key=operator.itemgetter(1), reverse=True)
#
# ~\anaconda3\lib\site-packages\RAKE\RAKE.py in generate_candidate_keyword_scores(phrase_list, word_score, minFrequency)
#     142     keyword_candidates = {}
#     143     for phrase in phrase_list:
# --> 144         if phrase_list.count(phrase) >= minFrequency:
#     145             keyword_candidates.setdefault(phrase, 0)
#     146             word_list = separate_words(phrase)
#
# KeyboardInterrupt:

# %%
keywords = [
    'magazine',
    'mag',
    'product',
    'magazine subscription',
    'subscription',
    'product',
    'publication',
    'purchase',
    'electronic version',
    'paper version',
    'print edition',
    'kindle edition',
    'reading material'
]

# %%
subscription_to = re.findall('subscription to .+?\.', '. '.join(files['reviewText'].tolist()))
len(subscription_to)
# Out:
# 1544

# %% [markdown]
# Просматривая контексты, удалось увидеть довольно частотное выражение subscription to, после которого, как правило, следует какое-то упоминание журнала. Вытащим эти упоминания.

# %%
ners = []
for text in subscription_to:
    text = nltk.word_tokenize(text)
    text = nltk.pos_tag(text)
    flag = False
    ner = []
    for word in text[2:]:
        if not flag:
            ner.append(word[0])
            if word[1] in ['NN', 'NNS', 'NNP', 'PRP']:
                flag=True
        else:
            if word[1] in ['NN', 'NNS', 'NNP', 'PRP']:
                ner.append(word[0])
            else:
                break
    if not flag:
        ner = []
    if ner:
        ners.append(' '.join(ner))

# %%
len(ners)
# Out:
# 1452

# %%
ners = list(set(ners))
len(ners)
# Out:
# 791

# %% [markdown]
# Отфильтруем по длине.

# %%
ners = [ner for ner in ners if len(ner) < 30]

# %%
ners
# Out:
# ['the paper copy',
#  'APR',
#  'SI',
#  'my sister',
#  'Maxim Magazine',
#  'the tablet version',
#  'this beautiful magazine',
#  'cover the issues I',
#  'Asimov',
#  'Family Tree magazine',
#  'my Army son',
#  'Gourmet Magazine',
#  'arrive because Amazon',
#  'deliver to my house',
#  'Newsweek',
#  'keep me',
#  'Food Network',
#  'be cancelled about 6 months',
#  'this mag FREE',
#  'two former New',
#  'be the best deal',
#  'AG magazine',
#  'digital-only , and each time',
#  'Philosophy',
#  'the USA',
#  'my Kindle',
#  'Wondertime',
#  'NY Review',
#  'this wonderful magazine/',
#  'Consumers Report',
#  'First',
#  'a collection agency',
#  'start but the first issue',
#  'Time Out New York',
#  'Quiltmaker',
#  'a boring magazine',
#  'get a Kindle-copy',
#  'Fine Cooking',
#  'make up for the lost issues',
#  'Backpacker magazine',
#  'the website',
#  'this incredible mag',
#  'OXM',
#  'Traditional Home Classics',
#  '5 friends',
#  'Blade magazine',
#  '`` People Magazine',
#  'Martha Stewart Living',
#  'an great magazine',
#  'open the articles',
#  'The Christian Century',
#  'Traditional Home',
#  'the local newspaper',
#  '`` Zoobooks',
#  'Redbook',
#  'bassmasters',
#  'all decorating enthusiasts',
#  'the print magazine',
#  'be something I',
#  'this publication',
#  'Discover',
#  'Country Living UK',
#  'Fantasy',
#  'Dog',
#  'his teacher',
#  'Scotland Magazine',
#  'PC World',
#  'Truck Round Up',
#  'Us Weekly magazine',
#  'her magazine',
#  'the hard-copy',
#  'off-load the previous month',
#  'Dwell',
#  'every rider',
#  'Car',
#  'this indispensible magazine',
#  'Bead',
#  'someone',
#  'Parents Magazine',
#  'my teen-age grandson',
#  'kindle and forced me',
#  'expire in July',
#  'Time mag',
#  'end , and I',
#  'RealSimple',
#  '`` Scientific American',
#  'Discovery Girls',
#  'tv guide magazine',
#  'two close friends',
#  'digital is the Kindle Fire',
#  'Food',
#  'start , but they',
#  'Forbes',
#  'Vogue',
#  'the Food Network magazine',
#  'the English language edition',
#  'PROFESSIONAL BEAUTY',
#  'field',
#  'their magazine',
#  'Runner',
#  '`` WIRED',
#  'NG World',
#  'WW magazine you',
#  'Horse',
#  'a magazine you',
#  'a great film magazine',
#  'a magazine',
#  'a neighbor teenage',
#  'begin , so I',
#  'my grandson',
#  'get the Kindle edition',
#  'this magazine I',
#  'this formerly good magazine',
#  'Road',
#  'P',
#  'your kindle app',
#  'People',
#  'this for my son',
#  'a magazine I',
#  'Sports Illustrated',
#  'GQ',
#  'just buy single issues',
#  'GO',
#  'Magnifikid',
#  'a relative and he',
#  'Kids',
#  'Old Cars Weekly',
#  'your niece',
#  'Guideposts',
#  'All You',
#  'my friend',
#  'a cooking magazine',
#  'PC Photo',
#  'Seventeen Magazine',
#  'WOI',
#  'the real Natl Geographic',
#  'Climbing',
#  'start working again , I',
#  'Ananlog SF',
#  'Popular Science Magazine',
#  'have if you',
#  'a Science magazine',
#  'the paper version',
#  'Babybug',
#  'Bon Appetit',
#  '`` Science News',
#  'save money',
#  '9 months',
#  '`` Men',
#  'both Fire',
#  'muscle',
#  'ShutterBug sight unseen',
#  'Time Magazine',
#  'Time magazine',
#  'San Diego Home-Garden',
#  'a Kindle one',
#  'Natural History',
#  'BH',
#  '`` Mental Floss',
#  'oprah and I',
#  'MAD- you',
#  'Playboy magazine',
#  'read on Kindle Fire',
#  'this for 50+ years',
#  'Midwest Living',
#  'the high school',
#  'my Mother',
#  'National Geographic',
#  'MC',
#  'the New Yorker',
#  'complement my printed copy',
#  'The Week',
#  'her favorite magazine',
#  'Readers Digest',
#  'extend to end of year',
#  'get the them',
#  'TIME magazine',
#  'all the magazines I',
#  'a science magazine',
#  'a service',
#  'be a Christmas present',
#  'get a different perspective',
#  'run , as I',
#  'O',
#  'any Chevrolet fan',
#  'this year',
#  'this text-only magazine',
#  'our kitchen staff',
#  'Pacific Standard',
#  'PB',
#  'Guitar World',
#  'Wired magazine',
#  'an artist friend',
#  'O magazine',
#  'a fashion magazine',
#  'the American Girl magazine',
#  'Islands Magazine',
#  'this one lapse',
#  'Amazon',
#  'evaluate this magazine',
#  'midwest living',
#  'Pop Photo',
#  'four different parenting',
#  'Nat Geo Mag',
#  'Nickelodeon',
#  'other family members',
#  'my teenage Nephew',
#  'Artists magazine',
#  'this for someone',
#  'TV Guide',
#  'Fine Homebuilding Magazine',
#  'a nice offer',
#  'Sports Illistrated',
#  'my most favored news magazine',
#  'Archaeology',
#  'this and just renewed it',
#  'get a teaser',
#  'Garden',
#  'Everyday Food',
#  'the Guardian Weekly',
#  'my SIL',
#  'receiving the first issue',
#  'Acreage',
#  'Cook',
#  'Outdoor Photograpy',
#  'ScienceDaily magazine',
#  'Triathlete Magazine',
#  'the paper mag',
#  'extend a subscription',
#  'actually arrive on my door',
#  'go into effect',
#  'have it home',
#  'the print edition',
#  'EM',
#  'this with the disc',
#  'friends',
#  'Islands',
#  'be cancelled , but they',
#  'MoJo',
#  'my friends',
#  'an English version I',
#  'Cat Fancy',
#  '`` do it yourself',
#  'see if he',
#  'the Little Kids publication',
#  'Das Neue Blatt',
#  'purchase on Amazon',
#  'help me',
#  'begin but I',
#  'Glamour',
#  'House Beautiful',
#  'All You Magazine',
#  'Saveur',
#  'Q I',
#  'The New Yorker',
#  'my Grand son',
#  'Investor',
#  'Vegetarian Times',
#  'Technology Magazine',
#  'my new kindle',
#  'something',
#  'Numismatic News',
#  'this rag',
#  'Cowboys',
#  'REAL SIMPLE',
#  'a quality magazine',
#  'the Arizona Highways',
#  'start at a reasonable time',
#  'a family member',
#  'New Yorker',
#  'Entertainment Weekly',
#  'the WSJ',
#  'Coastal Living',
#  'a second year',
#  'American Scientist',
#  'the U',
#  'Automobile',
#  'the web version',
#  'four photography magazines',
#  'Popular Science',
#  'the Economist expire',
#  '`` Popular Photography',
#  'People en Espanol',
#  'Good Housekeeping',
#  'grow with the child',
#  'start ? I',
#  'start sharing science',
#  'the electronic version',
#  'Elle Decor',
#  'Maxim',
#  'Mystery Scene',
#  're-install the app',
#  '`` German Life',
#  'lapse so I',
#  'SmartMoney',
#  'Writer',
#  'Men',
#  'this mag',
#  'renew every year',
#  'WatchTime magazine',
#  'nat geo',
#  'scale military modeller',
#  'Fast Company',
#  'try it',
#  'all my girlfriends',
#  'Young Rider',
#  'the magazine I',
#  'read The New Yorker',
#  'start ( 8 weeks',
#  'Country Living',
#  'Vanity Fair',
#  'Real Simple',
#  'food',
#  'ensure I',
#  'Money Magazine',
#  'AJN',
#  'my great grandson',
#  'my grandfather',
#  'the written version',
#  'Chirp',
#  'Oprah Magazine',
#  'style watch',
#  '`` Cooking Light',
#  'women',
#  'XBOX magazine',
#  'american girl magazine',
#  'Scientific American',
#  'anything',
#  'Golf Digest',
#  'Mental Floss',
#  'both in the past , I',
#  'O Magazine',
#  'the World',
#  'Ladybug',
#  'show my support',
#  'continue sending me invoices',
#  'MSL',
#  'CR',
#  'a newspaper',
#  'All You magazine',
#  'TNC',
#  'the print version',
#  'decide whether or not you',
#  'this magazine thinking',
#  'Shape',
#  'Popular Mechanics',
#  'defend freedom',
#  'Garden Railways',
#  'Ask',
#  'COSMOgirl',
#  'Farm World',
#  'the mail',
#  'Sports Illustrated Kids',
#  'the online version',
#  'renew in June',
#  'Wired',
#  'People Magazine',
#  '`` Writer',
#  'Allure',
#  'end because I',
#  'Veg Times',
#  'Outside magazine',
#  'Sunset Magazine',
#  'both the print',
#  'Discovery Girls magazine',
#  'Inc',
#  'start with the November issue',
#  'Analog Science Fiction',
#  'US',
#  'this `` newspaper',
#  'Studio Cin',
#  'my Dad',
#  'lapse',
#  'kindle comes about a week',
#  'Lucky this year',
#  'The New York Review',
#  'start , but once it',
#  'Doctor Who Magazine',
#  'my brother',
#  'the Economist',
#  'the latest incarnation',
#  'give to my son',
#  'the TV GUIDE',
#  'end so that I',
#  'Time a while',
#  'Sports Illus',
#  'get a refund',
#  'Essence',
#  'my daughter',
#  'a `` magazine',
#  'start home delivery',
#  'NY',
#  'start when the payment',
#  'receiving issues',
#  'Psychology Today',
#  'its current 4-6 is a slide',
#  'renewal via Amazon',
#  'V-Twin magazine',
#  'my grandkids',
#  'ESSENCE magazine',
#  'these guy',
#  'PLAYBOY',
#  'The Believer',
#  'health',
#  'compensate amd',
#  'my usual Amazon',
#  'for sure ! I',
#  'Entertainment Weekly ongoing',
#  'a mag',
#  'Mens Journal',
#  'TNY',
#  'NatGeo Traveler',
#  'Guns',
#  'this magazing',
#  'Logic Problems',
#  'NatGeo',
#  'Mad',
#  'this non-magazine',
#  'my order',
#  'Harper',
#  'over years',
#  'my relatives',
#  'my husband',
#  'BHG',
#  'Consumer Reports lapse',
#  'either Fanfare',
#  'MagnifiKid',
#  'Truckin',
#  'Parents',
#  'the UK version',
#  'Trains',
#  'Women',
#  'Money',
#  'the electronic version I',
#  'Parents lapse',
#  'see if it',
#  'Discover magazine',
#  'start ! I',
#  'BYO',
#  'kick in and I',
#  'have `` All Access',
#  'the LROB',
#  'Hiragana Times',
#  'Kindle version',
#  'March',
#  'the kindle version',
#  'the same magazine exists',
#  'arrive in the mail',
#  'Cooking Light',
#  'Comsumer Reports',
#  'Handyman',
#  'two of their magazines',
#  '`` Cook',
#  'NG',
#  'Popular',
#  'ESPN',
#  'WW Magazine',
#  'The Economist',
#  'Shotgun news',
#  'Shop Smart',
#  'All Receipes',
#  '`` Lucky',
#  'all my foodie friends',
#  'have it',
#  'my Grandson',
#  'G',
#  'make up for it',
#  'Man Magnum',
#  'the REAL',
#  'High Times',
#  'BB',
#  'Nat Geo',
#  'my adult son',
#  'my son',
#  'this one',
#  'the remaining time',
#  'Businessweek',
#  'the Oprah Magazine',
#  'me',
#  'getting the magazine',
#  'a popular magazine',
#  'Slate',
#  'Cosmopolitan magazine',
#  'Maximum PC',
#  'my 22 year',
#  'The Nation',
#  'Food Network magazine',
#  'Prevention',
#  'make up for the ones I',
#  'HBR',
#  'Business Week',
#  'Seventeen',
#  'keep my husband',
#  'start , but no luck',
#  'another magazine',
#  'Details on December',
#  "this & did n't like it",
#  'start , it',
#  'VF',
#  'begin , I',
#  'run out so I',
#  'this magazine years',
#  'the original 12-issues',
#  'my best friend',
#  'Esquire',
#  'this old friend',
#  'my kindle',
#  'Brio',
#  'tween and teen friends',
#  'Tricycle',
#  'our mother',
#  'this for Xmas',
#  'Fangoria',
#  'Art',
#  'receive Kindle edition',
#  'make up for the months I',
#  'Time',
#  'this magazineafter it',
#  'Marie Claire',
#  'Southwest Art',
#  'a car mag it',
#  'my old friend',
#  'Science News',
#  'a logic problems magazine',
#  'Guitar Player',
#  'the London Review',
#  'this fine publication',
#  'a certain magazine',
#  '`` Outdoor Photographer',
#  'Hola',
#  'Classic Motorsports',
#  'Yahoo Internet Life',
#  'my local library',
#  'Flute Talk',
#  'this last year',
#  'Cosmo',
#  'T',
#  'CL',
#  '`` Photo Ad Magazine',
#  'Click',
#  'magazines',
#  'BabyBug',
#  'Q',
#  'no avail',
#  'this newspaper',
#  'the Kindle Fire edition',
#  'this for the awesome price',
#  'highlights',
#  'National Geographic Traveler',
#  'Better Homes',
#  'October',
#  'Reason',
#  'Nintendo Power',
#  'Jack',
#  'end in feb 2013 when it',
#  'Newsweek when I',
#  'Prevention Magazine',
#  '`` Hola',
#  'People as part',
#  'Newsweek lapse',
#  'this product',
#  'make up for the mistake',
#  'this if you',
#  'Popular Mechanics Magazine',
#  'start , so I',
#  'the economist',
#  'others',
#  'The Old Schoolhouse',
#  'Spider',
#  'TIME',
#  'gourmet magazine',
#  'this as a gift',
#  'Ranger Rick',
#  'this kind',
#  'remind you',
#  'my one year',
#  '`` Opera News',
#  'REV magazine they',
#  'some obscure monthly that I',
#  'a friend',
#  '0 Magazine',
#  'newyorker',
#  're-commence',
#  'High Five',
#  'Food Network Magazine',
#  '`` O',
#  'my daughters',
#  'Real simple',
#  'National geographic',
#  'arrive , and Amazon',
#  'Outdoor Life',
#  'Sunset',
#  '`` Guideposts',
#  'Smartmoney magazine',
#  'start arriving',
#  'Girls Life',
#  'him',
#  'F',
#  '`` yet another news weekly',
#  'the mix',
#  'the yearly subscription',
#  'a favorite magazine',
#  'Newsweek when it',
#  'Vogue Magazine',
#  'end in December',
#  'Old House Journal',
#  'read on the tablet',
#  'start , and it',
#  'this magazine',
#  'my granddaughter',
#  'stay on top',
#  'TOH',
#  'my Wife',
#  'a business news publication',
#  'Dell',
#  'be REKNEWED',
#  'my favorite magazine',
#  'Computer Shopper',
#  'SOAP OPERA WEEKLY',
#  'this as a teenager',
#  'Outdoor Photography',
#  'Penthouse magazine',
#  'Aperture',
#  'Experience Life',
#  'both print',
#  'ALL YOU',
#  'Health magazine',
#  'Family Circle',
#  'the Test Kitchen website',
#  'a physical magazine',
#  'TIME Magazine',
#  'the Magazine',
#  'a really great magazine',
#  'PM',
#  'sports',
#  'this growing up , and i',
#  'save paper',
#  'stop I',
#  'the Kindle',
#  'the large print version',
#  'anyone',
#  'be downloaded to one device',
#  'Kindle',
#  'Outlook',
#  'this important magazine',
#  'this great magazine',
#  'Woman',
#  'the physical copy',
#  'motor trend',
#  'digital , and if I',
#  'Bicycling',
#  'Countryside',
#  'through the years',
#  'the rest',
#  'pharmaceutical ads',
#  'date',
#  "see what 's for sale",
#  'Marie Claire Magazine',
#  'PC Magazine',
#  'Sunset magazine',
#  'my dad',
#  'this amazing magazine',
#  '`` Handguns',
#  'TREADS',
#  'this , and glad I',
#  '`` Bride',
#  'Kiplinger',
#  'see if they',
#  'Kiplinger itself',
#  'avoid killing more trees',
#  'this relatively new magazine',
#  "`` one '' household",
#  'Soap Opera Digest',
#  'the woman',
#  'the address I',
#  '`` Cosmo',
#  '`` Outdoor Life',
#  'support her',
#  'History Ireland',
#  'navy times',
#  'COOKING LIGHT',
#  'US Weekly',
#  'just get ideas',
#  'Analog',
#  'one of my favorite magazines',
#  'Real Simple several times',
#  'Australia',
#  'Publisher',
#  'this arts',
#  'fix the problem',
#  'their on-line service',
#  'Us Weekly',
#  'Art Collector',
#  'the magazine',
#  'Running Times',
#  'it',
#  'PT',
#  'Oprah',
#  '`` Vegetarian Times',
#  'Playboy in more than a decade',
#  'this so it',
#  'PEOPLE if you',
#  'Fitness Rx',
#  'this for years',
#  'Animal Baby',
#  'lapse , and read it',
#  'O- Oprah magazine',
#  'elderly parents',
#  'this wonderful U',
#  "' O",
#  'support a child',
#  'this top notch magazine',
#  'Redbook magazine',
#  'the full year',
#  'a wonderful magazine',
#  'my mom',
#  'NG Kids',
#  'Babybug magazine',
#  'our children',
#  'a prolific',
#  'SciAm',
#  'the digital version',
#  'BHG magazine',
#  'this wonderful magazine',
#  'Narrative',
#  'the mag',
#  'start , but I',
#  'Cricket',
#  'all my friends',
#  'C',
#  'Simple',
#  'World',
#  'Southern Living',
#  'kick in but in the end it',
#  'check it',
#  'my wife',
#  'my Daughter',
#  'Hot Rod Magazine',
#  'People magazine',
#  'Country Living magazine',
#  'end with Dec/Jan',
#  'Bass Player expire',
#  'New Scientist',
#  'Glamour magazine',
#  'Golf Magazine',
#  'Reader',
#  'German Life magazine']

# %%
all_ners = meta_collocations + keywords + ners
len(all_ners)
# Out:
# 987

# %%
all_ners = list(set(all_ners))
len(all_ners)
# Out:
# 971

# %% [markdown]
# ### Получение n-грамм

# %%
all_ngrams = []
text = ' '.join(files['reviewText'].tolist())
for ner in tqdm(all_ners):
    ner_regex = re.sub(r'\(', r'\\(', ner)
    ner_regex = re.sub(r'\)', r'\\)', ner_regex)
    left = re.findall('([a-zA-Z0-9]+?)\s+?' + ner_regex, text)
    right = re.findall(ner_regex + '\s+?([a-zA-Z0-9]+?)[\s,.!?]', text)
    left = [((i, ner), ner) for i in left]
    right = [((ner, i), ner) for i in right]
    all_ngrams.extend(left)
    all_ngrams.extend(right)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=971.0), HTML(value='')))

# %%
len(all_ngrams)
# Out:
# 711002

# %% [markdown]
# ### Рассчет метрик
#
# Исключим нечастотные коллокации.

# %%
sum(ngrams_dict.values())
# Out:
# 711002

# %%
ngrams_dict = Counter(all_ngrams)
contexts = []
for key, value in ngrams_dict.items():
    if value > 10:
        contexts.extend([list(key[0])] * value)

# %%
len(contexts)
# Out:
# 562581

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()

# %%
finder = BigramCollocationFinder.from_documents(contexts)

# %%
finder.score_ngrams(bigram_measures.likelihood_ratio)[:20]
# Out:
# [(('this', 'mag'), 57874.77684766975),
#  (('this', 'magazine'), 36680.84646573786),
#  (('the', 'mag'), 26924.285956906922),
#  (('it', 'magazine'), 22292.053863407233),
#  (('it', 'it'), 20435.852432416163),
#  (('magazine', 'it'), 16875.137746479293),
#  (('the', 'magazine'), 15305.723245773275),
#  (('mag', 'it'), 14401.599794853028),
#  (('my', 'subscription'), 13394.138000176503),
#  (('love', 'this mag'), 10273.190939286467),
#  (('National', 'G'), 9890.977727257688),
#  (('This', 'mag'), 9853.915564929604),
#  (('magazine', 'me'), 9008.219290612404),
#  (('it', 'was'), 8064.994844098647),
#  (('it', 'me'), 8000.0905823639605),
#  (('magazine', 'this'), 8000.025660753329),
#  (('love', 'this magazine'), 7872.88275212774),
#  (('in', 'the mail'), 7814.143601390981),
#  (('my', 'Kindle'), 7539.185191890404),
#  (('it', 'this'), 7492.215796883381)]

# %%
finder.score_ngrams(bigram_measures.pmi)[:20]
# Out:
# [(('Biblical', 'Archaeology'), 16.401261585754856),
#  (('Ready', 'Mad'), 14.892247938267001),
#  (('REAL', 'SI'), 14.547112452218313),
#  (('Bloomberg', 'Businessweek'), 14.373780849332748),
#  (('Dog', 'Fancy'), 14.346813801732477),
#  (('Country', 'Woman'), 14.014238462645613),
#  (('been', 'getting the magazine'), 13.779773209008583),
#  (('Scientific American', 'Mind'), 13.658757808047223),
#  (('this magazine years', 'ago'), 13.65875780804722),
#  (('Practical', 'Horse'), 13.625967872929552),
#  (('Western', 'Horse'), 13.625967872929552),
#  (('Horse', 'Illustrated'), 13.183449637228602),
#  (('VERY', 'GO'), 13.08002726103758),
#  (('ESPN', 'Insider'), 12.700821867613765),
#  (('placing', 'my order'), 12.69231036775825),
#  (('placed', 'my order'), 12.692310367758243),
#  (('Art', 'Collector'), 12.658757808047223),
#  (('Quilting', 'Art'), 12.658757808047222),
#  (('Southwest', 'Art'), 12.658757808047216),
#  (('Philosophy', 'Now'), 12.570319843379634)]

# %%
finder.score_ngrams(bigram_measures.dice)[:20]
# Out:
# [(('Biblical', 'Archaeology'), 1.0),
#  (('Real', 'Simple'), 0.8059259259259259),
#  (('Bloomberg', 'Businessweek'), 0.691358024691358),
#  (('Dog', 'Fancy'), 0.6329113924050633),
#  (('Ready', 'Mad'), 0.5769230769230769),
#  (('Food', 'Network'), 0.5536480686695279),
#  (('Horse', 'Illustrated'), 0.5492957746478874),
#  (('this magazine years', 'ago'), 0.5128205128205128),
#  (('REAL', 'SI'), 0.4838709677419355),
#  (('Family', 'Handyman'), 0.4801670146137787),
#  (('Popular', 'Science'), 0.4548736462093863),
#  (('Country', 'Woman'), 0.41379310344827586),
#  (('placed', 'my order'), 0.411214953271028),
#  (('Popular', 'Mechanics'), 0.38178633975481613),
#  (('Western', 'Horse'), 0.3669724770642202),
#  (('this', 'mag'), 0.34291565073277397),
#  (('Practical', 'Horse'), 0.3364485981308411),
#  (('ESPN', 'Insider'), 0.33497536945812806),
#  (('VERY', 'GO'), 0.3333333333333333),
#  (('Fine', 'Woodwork'), 0.31958762886597936)]

# %% [markdown]
# В целом вышла какая-то беда. Мне кажется, это может быть связано с тем, что нередко названия журналов сокращаются до слова. Например 'Bloomberg Businessweek' могут назвать просто Businessweek, но сочетание 'Bloomberg Businessweek' будет более частотно, чем прилагательное + 'Bloomberg Businessweek' или прилагательное + Businessweek. Возможно, стоило поработать с шаблонами при выделении контекстов в том числе. Но в целом мне кажется, что pmi и dice справляются лучше, чем likelihood_ratio, потому что вытаскивают более концептуальные коллокации, названия, а не просто общеупотребительные слова и в целом у них выдача довольно похожа.

# %% [markdown]
# ### Примеры

# %%
candidates = ['mag', 'magazine', 'subscription', 'Vogue', 'product']

# %%
ordered_ngram_dict = OrderedDict(sorted(ngrams_dict.items(), key=lambda x: x[1], reverse=True))
for candidate in candidates:
    collocs = [' '.join(k[0]) for k in ordered_ngram_dict.keys() if k[1] == candidate][:5]
    print(candidate + '\n' + '\n'.join(collocs))
    print('\n')
# Out:
# mag
# this mag
# the mag
# This mag
# a mag
# great mag
#
#
# magazine
# this magazine
# the magazine
# magazine is
# magazine for
# This magazine
#
#
# subscription
# my subscription
# a subscription
# the subscription
# subscription to
# subscription for
#
#
# Vogue
# Teen Vogue
# Vogue is
# Vogue and
# of Vogue
# to Vogue
#
#
# product
# the product
# product reviews
# new product
# this product
# and product
